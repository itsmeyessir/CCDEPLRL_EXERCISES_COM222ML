# %% [markdown]
# # Exercise 4

# %% [markdown]
# ## Instructions
#
#
# 1. Collect **100-200 images** of the fruit
# 2. Split the collected images for train, test and validation. Please make sure that there are no duplicate images. Images that are used in train should not appear in test, validation and vice versa.
# 3. Combine the collected images together with the images of apple, orange and banana. They  are already available in the link below: https://github.com/robitussin/tensorflow_lite_projects/tree/main/images/fruits
# 4. Create and train a Convolutional Neural Network (CNN).
# 5. Save the model as **"model.tflite"**
# 6. Create a folder named **exercise_4** in your **CCDEPLRL_EXERCISES_COM222_ML** repository.
# 7. Upload the **python notebook (.ipynb)** and the **model (.tflite)** in the exercise_3 folder
#
# Deadline of submission is on **April 22, 2025**

# %% [markdown]
# ## Model

# %% [markdown]
# Import the libraries

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# Hyperparameters: Set the image size and batch size

# %%
img_height, img_width = 32, 32
batch_size = 20

# %% [markdown]
# Split the images into train, validation and test

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    "fruits/train",
    image_size = (img_height, img_width),
    batch_size = batch_size
)
val_ds = tf.keras.utils.image_dataset_from_directory(
    "fruits/validation",
    image_size = (img_height, img_width),
    batch_size = batch_size
)
test_ds = tf.keras.utils.image_dataset_from_directory(
    "fruits/test",
    image_size = (img_height, img_width),
    batch_size = batch_size
)
# Out:
# Found 540 files belonging to 4 classes.
# Found 76 files belonging to 4 classes.
# Found 140 files belonging to 4 classes.

# %% [markdown]
# Display sample images from the dataset

# %%
class_names = ["apple", "banana", "orange", "peach"]
plt.figure(figsize=(10,10))
for images, labels in train_ds.take(1):
  for i in range(16):
    ax = plt.subplot(4, 4, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# Create the Convolutional Neural Network Model (CNN)

# %%
model = tf.keras.Sequential(
    [
     tf.keras.layers.Rescaling(1./255),
     tf.keras.layers.Conv2D(32, 4, activation="relu"),
     tf.keras.layers.MaxPooling2D(),
     tf.keras.layers.Conv2D(32, 4, activation="relu"),
     tf.keras.layers.MaxPooling2D(),
     tf.keras.layers.Conv2D(32, 4, activation="relu"),
     tf.keras.layers.MaxPooling2D(),
     tf.keras.layers.Flatten(),
     tf.keras.layers.Dense(128, activation="relu"),
     tf.keras.layers.Dense(4)
    ]
)

# %% [markdown]
# Define the optimizer and loss function

# %%
model.compile(
    optimizer="adam",
    loss=tf.losses.SparseCategoricalCrossentropy(from_logits = True),
    metrics=['accuracy']
)

# %% [markdown]
# Train the model

# %%
model.fit(
    train_ds,
    validation_data = val_ds,
    epochs = 100
)
# Out:
# Epoch 1/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - accuracy: 0.4148 - loss: 1.3133 - val_accuracy: 0.5526 - val_loss: 1.0462
# Epoch 2/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.5811 - loss: 1.0077 - val_accuracy: 0.6711 - val_loss: 0.7229
# Epoch 3/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.7134 - loss: 0.7722 - val_accuracy: 0.7763 - val_loss: 0.5755
# Epoch 4/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.7738 - loss: 0.6097 - val_accuracy: 0.8421 - val_loss: 0.4771
# Epoch 5/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.8525 - loss: 0.4179 - val_accuracy: 0.8553 - val_loss: 0.4719
# Epoch 6/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8656 - loss: 0.3884 - val_accuracy: 0.8553 - val_loss: 0.4756
# Epoch 7/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - accuracy: 0.8418 - loss: 0.3906 - val_accuracy: 0.8947 - val_loss: 0.3815
# Epoch 8/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.8969 - loss: 0.2744 - val_accuracy: 0.8816 - val_loss: 0.3455
# Epoch 9/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.9517 - loss: 0.1913 - val_accuracy: 0.8947 - val_loss: 0.3590
# Epoch 10/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9257 - loss: 0.2100 - val_accuracy: 0.8684 - val_loss: 0.4383
# Epoch 11/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.9607 - loss: 0.1298 - val_accuracy: 0.8289 - val_loss: 0.5148
# Epoch 12/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.9562 - loss: 0.1370 - val_accuracy: 0.8684 - val_loss: 0.4303
# Epoch 13/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9599 - loss: 0.1502 - val_accuracy: 0.8553 - val_loss: 0.4742
# Epoch 14/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9462 - loss: 0.1438 - val_accuracy: 0.9079 - val_loss: 0.4085
# Epoch 15/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9757 - loss: 0.0963 - val_accuracy: 0.9342 - val_loss: 0.3087
# Epoch 16/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.
# Epoch 84/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 1.0000 - loss: 2.2248e-04 - val_accuracy: 0.9079 - val_loss: 0.7583
# Epoch 85/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 1.0000 - loss: 2.0265e-04 - val_accuracy: 0.9079 - val_loss: 0.7610
# Epoch 86/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 1.0000 - loss: 1.9705e-04 - val_accuracy: 0.9079 - val_loss: 0.7587
# Epoch 87/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 1.0000 - loss: 2.3861e-04 - val_accuracy: 0.9079 - val_loss: 0.7643
# Epoch 88/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - accuracy: 1.0000 - loss: 2.1069e-04 - val_accuracy: 0.9079 - val_loss: 0.7679
# Epoch 89/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 1.0000 - loss: 2.1364e-04 - val_accuracy: 0.9079 - val_loss: 0.7684
# Epoch 90/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 1.0000 - loss: 1.9371e-04 - val_accuracy: 0.9079 - val_loss: 0.7769
# Epoch 91/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 1.0000 - loss: 2.0647e-04 - val_accuracy: 0.9079 - val_loss: 0.7728
# Epoch 92/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 1.0000 - loss: 1.9351e-04 - val_accuracy: 0.9079 - val_loss: 0.7774
# Epoch 93/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 1.0000 - loss: 1.6691e-04 - val_accuracy: 0.9079 - val_loss: 0.7844
# Epoch 94/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 1.0000 - loss: 1.5483e-04 - val_accuracy: 0.9079 - val_loss: 0.7812
# Epoch 95/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 1.0000 - loss: 1.7853e-04 - val_accuracy: 0.9079 - val_loss: 0.7891
# Epoch 96/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 1.0000 - loss: 1.3957e-04 - val_accuracy: 0.9079 - val_loss: 0.7880
# Epoch 97/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 1.0000 - loss: 1.2224e-04 - val_accuracy: 0.9079 - val_loss: 0.7923
# Epoch 98/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 1.0000 - loss: 1.6871e-04 - val_accuracy: 0.9079 - val_loss: 0.7962
# Epoch 99/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 1.0000 - loss: 1.4333e-04 - val_accuracy: 0.9079 - val_loss: 0.7940
# Epoch 100/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 1.0000 - loss: 1.1375e-04 - val_accuracy: 0.9079 - val_loss: 0.8021

# %% [markdown]
# Test the model

# %%
model.evaluate(test_ds)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.9831 - loss: 0.0772
# [0.15194101631641388, 0.9714285731315613]

# %%
import numpy

plt.figure(figsize=(10,10))
for images, labels in test_ds.take(1):
  classifications = model(images)
  # print(classifications)

  for i in range(16):
    ax = plt.subplot(4, 4, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    index = numpy.argmax(classifications[i])
    plt.title("Pred: " + class_names[index] + " | Real: " + class_names[labels[i]])

# %%
import numpy as np
import matplotlib.pyplot as plt

peach_images = []
peach_preds = []
peach_labels = []

for images, labels in test_ds:
    predictions = model(images)

    for i in range(len(images)):
        pred_index = np.argmax(predictions[i])
        label_index = labels[i].numpy()

        if class_names[pred_index] == "peach" or class_names[label_index] == "peach":
            peach_images.append(images[i])
            peach_preds.append(class_names[pred_index])
            peach_labels.append(class_names[label_index])

        if len(peach_images) >= 16:
            break
    if len(peach_images) >= 16:
        break

num_peach_images = len(peach_images)

plt.figure(figsize=(10, 10))
for i in range(num_peach_images):
    ax = plt.subplot(4, 4, i + 1)
    plt.imshow(peach_images[i].numpy().astype("uint8"))
    plt.title(f"Pred: {peach_preds[i]} | Real: {peach_labels[i]}", fontsize=9)
    plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# Save the model

# %%
model.save('fruits_model.keras')
